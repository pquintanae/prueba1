# %% [markdown]
# # Tutorial

# %% [markdown]
# ## Instalar paqueterías desde terminal (cmd o anaconda prompt)
# conda install openpyxl

# %% [markdown]
# ## Instalar paquetería desde python

# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %% [markdown]
# ### Nota: Luego de instalar, reiniciar kernell (menú: Kernel > Restart Kernel)

# %% [markdown]
# ## Llamar paquetes inslatados

# %%
import pandas as pd
import os #te permite ver/cambiar tu ruta de trabajo

# %% [markdown]
# ## Ver y cambiar ruta actual de trabajo

# %%
os.getcwd() #ver ruta de trabajo
os.chdir("C:\\Users\\Yzula Tec\\Documentos\\proyecto_git\\python")#cambiar ruta de trabajo
os.getcwd()
# Out:
# 'C:\\Users\\Yzula Tec\\Documentos\\proyecto_git\\python'

# %% [markdown]
# ## Importar data excel

# %%
data=pd.read_excel("Tabla de datos.xlsx",sheet_name="Datos",skiprows=1) #skiprows: saltar filas del encabezado
data
# Out:
#     Nº de campaña                Fecha  Profundidad          (m) Estación  \
# 0               1           26/11/2024                       1.5    FE-01
# 1               1           26/11/2024                       1.5    TB-02
# 2               1           26/11/2024                       1.5    ER-03
# 3               1           26/11/2024                       1.5    PP-04
# 4               1           26/11/2024                       1.5   BCH-05
# 5               2           30/11/2024                       1.5    FE-01
# 6               2           30/11/2024                       1.5    TB-02
# 7               2           30/11/2024                       1.5    ER-03
# 8               2           30/11/2024                       1.5    PP-04
# 9               2           30/11/2024                       1.5   BCH-05
# 10              3  2024-06-12 00:00:00                       1.5    FE-01
# 11              3  2024-06-12 00:00:00                       1.5    TB-02
# ...

# %% [markdown]
# ## Ver resumen descriptivo de data

# %%
data.describe()
# Out:
#        Nº de campaña  Profundidad          (m)    Latitud   Longitud  \
# count      50.000000                      50.0  50.000000  50.000000
# mean        5.500000                       1.5   8.649362 -79.835066
# std         2.901442                       0.0   0.011726   0.017170
# min         1.000000                       1.5   8.638700 -79.852280
# 25%         3.000000                       1.5   8.638770 -79.847370
# 50%         5.500000                       1.5   8.644750 -79.841400
# 75%         8.000000                       1.5   8.655510 -79.829670
# max        10.000000                       1.5   8.669080 -79.804610
#
#        Distancia          (km)  Distancia  acumulada        (km)  \
# count                49.000000                         50.000000
# mean                  1.667347                          3.850000
# std                   0.905593                          2.846975
# min                   0.000000                          0.000000
# ...
